# %%
import math

AmountOfUsd = float(input("Amount of USD: "))
exchangeToVnd = AmountOfUsd * 22967.50
print("For {AmountOfUsd}$ you got {exchangeToVnd}VND".format(AmountOfUsd=AmountOfUsd, exchangeToVnd=exchangeToVnd))
# Out:
# Amount of USD: 10
# For 10.0$ you got 229675.0VND
